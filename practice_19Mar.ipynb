# %%
conda activate ai-agent
# Out:
# Note: you may need to restart the kernel to use updated packages.
# CondaError: Run 'conda init' before 'conda activate'

# %%
conda init
# Out:
# no change     C:\Users\vinay\anaconda3\Scripts\conda.exe
# no change     C:\Users\vinay\anaconda3\Scripts\conda-env.exe
# no change     C:\Users\vinay\anaconda3\Scripts\conda-script.py
# no change     C:\Users\vinay\anaconda3\Scripts\conda-env-script.py
# no change     C:\Users\vinay\anaconda3\condabin\conda.bat
# no change     C:\Users\vinay\anaconda3\Library\bin\conda.bat
# no change     C:\Users\vinay\anaconda3\condabin\_conda_activate.bat
# no change     C:\Users\vinay\anaconda3\condabin\rename_tmp.bat
# no change     C:\Users\vinay\anaconda3\condabin\conda_auto_activate.bat
# no change     C:\Users\vinay\anaconda3\condabin\conda_hook.bat
# no change     C:\Users\vinay\anaconda3\Scripts\activate.bat
# no change     C:\Users\vinay\anaconda3\condabin\activate.bat
# no change     C:\Users\vinay\anaconda3\condabin\deactivate.bat
# modified      C:\Users\vinay\anaconda3\Scripts\activate
# modified      C:\Users\vinay\anaconda3\Scripts\deactivate
# ...

# %%
conda activate ai-agent
# Out:
# Note: you may need to restart the kernel to use updated packages.
# CondaError: Run 'conda init' before 'conda activate'

# %%
conda init
# Out:
# no change     C:\Users\vinay\anaconda3\Scripts\conda.exe
# no change     C:\Users\vinay\anaconda3\Scripts\conda-env.exe
# no change     C:\Users\vinay\anaconda3\Scripts\conda-script.py
# no change     C:\Users\vinay\anaconda3\Scripts\conda-env-script.py
# no change     C:\Users\vinay\anaconda3\condabin\conda.bat
# no change     C:\Users\vinay\anaconda3\Library\bin\conda.bat
# no change     C:\Users\vinay\anaconda3\condabin\_conda_activate.bat
# no change     C:\Users\vinay\anaconda3\condabin\rename_tmp.bat
# no change     C:\Users\vinay\anaconda3\condabin\conda_auto_activate.bat
# no change     C:\Users\vinay\anaconda3\condabin\conda_hook.bat
# no change     C:\Users\vinay\anaconda3\Scripts\activate.bat
# no change     C:\Users\vinay\anaconda3\condabin\activate.bat
# no change     C:\Users\vinay\anaconda3\condabin\deactivate.bat
# no change     C:\Users\vinay\anaconda3\Scripts\activate
# no change     C:\Users\vinay\anaconda3\Scripts\deactivate
# ...

# %%
conda activate ai-agent
# Out:
# Note: you may need to restart the kernel to use updated packages.
# CondaError: Run 'conda init' before 'conda activate'

# %%
conda list
# Out:
# # packages in environment at C:\Users\vinay\anaconda3:
# #
# # Name                             Version               Build                Channel
# _anaconda_depends                  2025.12               py313_mkl_0
# aext-assistant                     4.20.0                py313haa95532_jl4_0
# aext-assistant-server              4.20.0                py313haa95532_0
# aext-core                          4.20.0                py313haa95532_jl4_0
# aext-core-server                   4.20.0                py313haa95532_0
# aext-environments-server           4.20.0                py313haa95532_0
# aext-panels                        4.20.0                py313haa95532_0
# aext-panels-server                 4.20.0                py313haa95532_0
# aext-project-filebrowser-server    4.20.0                py313haa95532_0
# aext-share-notebook                4.20.0                py313haa95532_0
# aext-share-notebook-server         4.20.0                py313haa95532_0
# ...

# %%
conda list langchain
# Out:
# Note: you may need to restart the kernel to use updated packages.
# CondaValueError: No packages match 'langchain'.

# %%
import numpy
import pandas
import langchain

print (numpy._version_)
print (pandas._version_)
print (langchain._version_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 5
#       2 import pandas
#       3 import langchain
# ----> 5 print (numpy._version_)
#       6 print (pandas._version_)
#       7 print (langchain._version_)
#
# File ~\anaconda3\Lib\site-packages\numpy\__init__.py:795, in __getattr__(attr)
#     792     import numpy.char as char
#     793     return char.chararray
# --> 795 raise AttributeError(f"module {__name__!r} has no attribute {attr!r}")
#
# AttributeError: module 'numpy' has no attribute '_version_'

# %%
pip install langchain
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show langchain
# Out:
# Name: langchain
# Version: 1.2.12
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: C:\Users\vinay\anaconda3\Lib\site-packages
# Requires: langchain-core, langgraph, pydantic
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
conda create -n ai-agent python=3.10
conda activate ai-agent
# Out:
#   Cell In[2], line 1
#     conda create -n ai-agent python=3.10
#           ^
# SyntaxError: invalid syntax

# %%
pip show python
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Package(s) not found: python

# %%
conda init ai-agent
# Out:
# Note: you may need to restart the kernel to use updated packages.
# usage: conda-script.py init [-h] [--all] [--condabin] [--user] [--no-user]
#                             [--system] [--reverse] [--anaconda-prompt]
#                             [--json] [--console CONSOLE] [-v] [-q] [-d]
#                             [SHELLS ...]
# conda-script.py init: error: argument SHELLS: invalid choice: 'ai-agent' (choose from bash, cmd.exe, fish, tcsh, xonsh, zsh, powershell)

# %%
bash
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 bash
#
# NameError: name 'bash' is not defined

# %%
print ("hello")
# Out:
# hello
